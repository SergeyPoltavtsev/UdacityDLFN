# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

## Your code here
threshold = 1e-5
word_count = Counter(int_words)
total_count = len(int_words)
freqs = {word: word_count/total_count for word, word_count in word_count.items()}
probs = {word: 1-np.sqrt(threshold/freq) for word, freq in freqs.items()}
train_words = [word for word in int_words if random.random() < (1 - probs[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if idx - R > 0 else 0
    stop = idx + R
    targets = list(set(words[start:idx] + words[idx+1:stop+1]))
    return targets

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory 'checkpoints': File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 10000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6140 0.1010 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6213 0.0984 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5275 0.0982 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5751 0.0985 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5125 0.0984 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5315 0.0985 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5522 0.0986 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5367 0.0992 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4945 0.1012 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4172 0.1019 sec/batch
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4975 0.1031 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3827 0.1036 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2853 0.1046 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2655 0.1047 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1770 0.1047 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1471 0.1055 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1047 0.1060 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0837 0.1057 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0060 0.1057 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9747 0.1061 sec/batch
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9483 0.1065 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8801 0.1065 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8730 0.1065 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8689 0.1065 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8059 0.1071 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8232 0.1067 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7861 0.1068 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8107 0.1067 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7809 0.1069 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7654 0.1070 sec/batch
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7646 0.1069 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7555 0.1080 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7166 0.1083 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7137 0.1084 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7397 0.1088 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7135 0.1082 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6980 0.1076 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7481 0.1076 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6908 0.1080 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6557 0.1075 sec/batch
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6607 0.1075 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6659 0.1079 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6098 0.1080 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6393 0.1084 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6117 0.1083 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6131 0.1077 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6074 0.0795 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5594 0.1079 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5207 0.1075 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4921 0.1074 sec/batch
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4784 0.1075 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5031 0.1076 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4603 0.1075 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5207 0.1077 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4852 0.1078 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4767 0.1084 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4457 0.1082 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3954 0.1085 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4378 0.1087 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4563 0.1086 sec/batch
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4285 0.1085 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4192 0.1084 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4143 0.1082 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3753 0.1082 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4015 0.1076 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4499 0.1079 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3657 0.1078 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4142 0.1081 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4233 0.1081 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3590 0.1071 sec/batch
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3765 0.1073 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3876 0.1077 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3733 0.1073 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.4045 0.1071 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3727 0.1073 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3693 0.1070 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3949 0.1076 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3937 0.1078 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3407 0.1082 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3169 0.1081 sec/batch
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3326 0.1083 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2840 0.1084 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3838 0.1077 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3872 0.1074 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3663 0.1077 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2654 0.1076 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3176 0.1076 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3334 0.1071 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2242 0.1079 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2990 0.1079 sec/batch
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2836 0.1076 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3169 0.1078 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3387 0.0501 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2403 0.1075 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2230 0.1076 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2041 0.1073 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1940 0.1071 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2010 0.1073 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1923 0.1076 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1673 0.1079 sec/batch
# Nearest to system: invertible, educational, corp, microsystems, montrealers, efficiencies, multiethnic, scam,
# Nearest to of: registered, joins, reflection, icd, candid, extend, leases, luxemburg,
# Nearest to had: soon, his, ihs, opposition, halted, goatskin, nunn, headlining,
# Nearest to as: the, reproduces, lovable, clift, danceable, cloaks, leven, indie,
# Nearest to by: tedious, misrepresentation, november, wendish, legislative, recognizing, seized, operation,
# Nearest to known: denormalization, duckling, akkadian, modern, deserved, spectrum, handset, greatly,
# Nearest to at: timespan, sra, rounds, antioch, loge, points, sowed, crouch,
# Nearest to american: gfdl, wark, mouseketeers, actor, lester, villard, wf, contact,
# Nearest to troops: forces, guadeloupe, urraca, aftermath, uprising, siege, drowns, provoking,
# Nearest to resources: hurricanes, bute, biodiversity, commodities, sausages, schoolteacher, acquisition, desertification,
# Nearest to recorded: patti, dramatised, soundtrack, garage, hyperlinked, toaster, attest, comforted,
# Nearest to accepted: flirty, conceptions, exceptionalism, lugano, sarcasm, pakistanis, inglis, dogs,
# Nearest to channel: ellipsoidal, philatelic, ubiquitous, cahiers, seasonings, parabellum, multics, majestic,
# Nearest to police: aloysius, homers, reedy, dict, defile, deregulation, qxd, cinerama,
# Nearest to operations: portobello, inverse, adoption, partitas, sixxs, tuples, jafar, lanes,
# Nearest to bible: jesus, scriptures, testament, ital, preface, synagogues, caesarea, epistle,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2297 0.1087 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2492 0.1076 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2345 0.1085 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1416 0.1086 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1980 0.1089 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1623 0.1094 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1701 0.1080 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1636 0.1082 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1974 0.1081 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2006 0.1086 sec/batch
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1720 0.1084 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2190 0.1076 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1384 0.1075 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1473 0.1076 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1768 0.1078 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2072 0.1082 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2074 0.1077 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1598 0.1076 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1287 0.1075 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1868 0.1073 sec/batch
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2315 0.1076 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1640 0.1076 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1677 0.1072 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1947 0.1078 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1292 0.1078 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1333 0.1083 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1718 0.1080 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1278 0.1083 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2065 0.1075 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2334 0.1079 sec/batch
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2139 0.1073 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1308 0.1079 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1292 0.1073 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1354 0.1077 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0466 0.1077 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1585 0.1077 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1729 0.1076 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1310 0.1076 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1726 0.0210 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1108 0.1077 sec/batch
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0874 0.1077 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0704 0.1077 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0895 0.1072 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0514 0.1077 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0755 0.1079 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0063 0.1075 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1320 0.1072 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0881 0.1079 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1270 0.1085 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0196 0.1087 sec/batch
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0166 0.1082 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0302 0.1090 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0101 0.1083 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0446 0.1079 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0770 0.1088 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0523 0.1088 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0525 0.1084 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1272 0.1075 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0728 0.1079 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0621 0.1079 sec/batch
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0412 0.1077 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0891 0.1077 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0636 0.1073 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0751 0.1068 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0776 0.1073 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0584 0.1076 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0656 0.1076 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0555 0.1076 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0734 0.1075 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0751 0.1072 sec/batch
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0543 0.1084 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9974 0.1086 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0213 0.1082 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0621 0.1083 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0647 0.1077 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1106 0.1073 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1201 0.1078 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0593 0.1079 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0264 0.1079 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0304 0.1071 sec/batch
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9538 0.1076 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0276 0.1079 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0525 0.1077 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0266 0.1073 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0805 0.1071 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0206 0.0993 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9933 0.1075 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9827 0.1073 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0289 0.1071 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9868 0.1074 sec/batch
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9899 0.1072 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9054 0.1076 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0242 0.1069 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0149 0.1082 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0288 0.1080 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9890 0.1081 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9136 0.1082 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9494 0.1086 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9381 0.1086 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9910 0.1086 sec/batch
# Nearest to system: multiethnic, educational, routes, universal, coeducational, montrealers, kempo, configurations,
# Nearest to of: the, by, melachim, in, and, tomorrowland, is, juveniles,
# Nearest to had: soon, his, maclennan, annob, halted, galego, debasement, was,
# Nearest to as: the, contrast, is, flashy, epistola, wmap, of, diacritical,
# Nearest to by: of, the, seized, given, s, rounding, simpler, junctions,
# Nearest to known: feldspars, duckling, greatly, spectrum, denormalization, dichromate, editing, squeak,
# Nearest to at: ninety, timespan, antioch, fencer, sowed, wakefield, up, thousands,
# Nearest to american: contact, gfdl, emigrants, actor, dillinger, prominently, makeup, wark,
# Nearest to troops: forces, battle, banner, peacekeeping, request, guadeloupe, isaf, authorizes,
# Nearest to resources: arable, hurricanes, alfalfa, natural, hydropower, invoices, schoolteacher, desertification,
# Nearest to recorded: patti, soundtrack, songs, singles, demo, vangelis, dogg, exclaimed,
# Nearest to accepted: lugano, asean, automated, flammable, exceptionalism, inglis, laminal, rad,
# Nearest to channel: ellipsoidal, philatelic, upn, harrington, cahiers, screened, kcr, majestic,
# Nearest to police: enforcement, passports, aloysius, commit, scare, writs, dict, jail,
# Nearest to operations: operation, tuples, indexed, inverse, war, jafar, sixxs, decimalisation,
# Nearest to bible: synagogues, apostolic, jps, scriptures, neuro, enlarged, redacted, ital,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0002 0.1094 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0066 0.1080 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9507 0.1080 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0133 0.1077 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0518 0.1075 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9316 0.1079 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9990 0.1076 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9737 0.1074 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0230 0.1072 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0027 0.1076 sec/batch
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0185 0.1077 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9847 0.1074 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0005 0.1070 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9776 0.1073 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0247 0.1077 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9995 0.1073 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9636 0.1079 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9773 0.1079 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9888 0.1079 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0371 0.1084 sec/batch
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9533 0.1075 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1092 0.1077 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0204 0.1075 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0255 0.1076 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9558 0.1076 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9362 0.1073 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9566 0.1071 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9274 0.1076 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9863 0.1078 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9671 0.1076 sec/batch
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 4.0055 0.1068 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 3.9820 0.0701 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 3.9576 0.1076 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 3.9359 0.1071 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 3.9733 0.1065 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 3.9177 0.1071 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 3.9592 0.1068 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 3.8994 0.1074 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 3.9622 0.1069 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 3.9642 0.1068 sec/batch
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 3.9606 0.1071 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 3.9743 0.1082 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.8666 0.1082 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.9526 0.1088 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.9129 0.1083 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.8858 0.1080 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 3.9173 0.1078 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 3.9813 0.1083 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.9244 0.1077 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 3.9420 0.1077 sec/batch
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 4.0292 0.1077 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 3.9048 0.1080 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.9065 0.1083 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.9654 0.1076 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.9518 0.1078 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 3.9439 0.1075 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.9558 0.1075 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.9241 0.1075 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 3.9370 0.1067 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 3.9734 0.1072 sec/batch
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 3.9587 0.1069 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 3.9515 0.1068 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 3.9659 0.1080 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 3.8950 0.1086 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 3.9315 0.1080 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 3.9383 0.1086 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 3.8954 0.1082 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 4.0163 0.1077 sec/batch
# Epoch 6/10 Iteration: 26900 Avg. Training loss: 4.0018 0.1077 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 4.0010 0.1073 sec/batch
# Epoch 6/10 Iteration: 27100 Avg. Training loss: 3.9093 0.1076 sec/batch
# Epoch 6/10 Iteration: 27200 Avg. Training loss: 3.8949 0.1072 sec/batch
# Epoch 6/10 Iteration: 27300 Avg. Training loss: 3.9555 0.1073 sec/batch
# Epoch 6/10 Iteration: 27400 Avg. Training loss: 3.8592 0.1076 sec/batch
# Epoch 6/10 Iteration: 27500 Avg. Training loss: 3.9488 0.1076 sec/batch
# Epoch 6/10 Iteration: 27600 Avg. Training loss: 3.9820 0.1072 sec/batch
# Epoch 6/10 Iteration: 27700 Avg. Training loss: 3.9367 0.1076 sec/batch
# Epoch 7/10 Iteration: 27800 Avg. Training loss: 3.9878 0.0415 sec/batch
# Epoch 7/10 Iteration: 27900 Avg. Training loss: 3.9141 0.1078 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 3.9052 0.1069 sec/batch
# Epoch 7/10 Iteration: 28100 Avg. Training loss: 3.8844 0.1066 sec/batch
# Epoch 7/10 Iteration: 28200 Avg. Training loss: 3.9187 0.1064 sec/batch
# Epoch 7/10 Iteration: 28300 Avg. Training loss: 3.8848 0.1071 sec/batch
# Epoch 7/10 Iteration: 28400 Avg. Training loss: 3.8851 0.1073 sec/batch
# Epoch 7/10 Iteration: 28500 Avg. Training loss: 3.8621 0.1073 sec/batch
# Epoch 7/10 Iteration: 28600 Avg. Training loss: 3.9523 0.1076 sec/batch
# Epoch 7/10 Iteration: 28700 Avg. Training loss: 3.8935 0.1075 sec/batch
# Epoch 7/10 Iteration: 28800 Avg. Training loss: 3.9464 0.1080 sec/batch
# Epoch 7/10 Iteration: 28900 Avg. Training loss: 3.8323 0.1081 sec/batch
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 3.8554 0.1085 sec/batch
# Epoch 7/10 Iteration: 29100 Avg. Training loss: 3.9314 0.1087 sec/batch
# Epoch 7/10 Iteration: 29200 Avg. Training loss: 3.8228 0.1083 sec/batch
# Epoch 7/10 Iteration: 29300 Avg. Training loss: 3.8769 0.1084 sec/batch
# Epoch 7/10 Iteration: 29400 Avg. Training loss: 3.9450 0.1082 sec/batch
# Epoch 7/10 Iteration: 29500 Avg. Training loss: 3.8834 0.1083 sec/batch
# Epoch 7/10 Iteration: 29600 Avg. Training loss: 3.9178 0.1076 sec/batch
# Epoch 7/10 Iteration: 29700 Avg. Training loss: 3.9566 0.1074 sec/batch
# Epoch 7/10 Iteration: 29800 Avg. Training loss: 3.8902 0.1081 sec/batch
# Epoch 7/10 Iteration: 29900 Avg. Training loss: 3.8697 0.1079 sec/batch
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 3.9161 0.1081 sec/batch
# Nearest to system: systems, multiethnic, whitcomb, universal, educational, local, routes, saf,
# Nearest to of: the, by, in, and, is, as, a, also,
# Nearest to had: was, his, soon, he, found, been, koktebel, heuss,
# Nearest to as: the, is, of, in, contrast, now, was, by,
# Nearest to by: the, of, for, a, on, s, an, which,
# Nearest to known: dubbed, feldspars, as, resembles, duckling, banner, blunder, was,
# Nearest to at: ninety, mellin, higher, of, timespan, twice, up, thousands,
# Nearest to american: gfdl, dillinger, contact, prominently, makeup, actor, japh, fetish,
# Nearest to troops: battle, forces, confederates, request, banner, peacekeeping, gunboat, gen,
# Nearest to resources: arable, hurricanes, extremes, schoolteacher, invoices, provides, alfalfa, hydropower,
# Nearest to recorded: patti, singles, demo, songs, dogg, gross, sanusi, lp,
# Nearest to accepted: lugano, automated, exceptionalism, leni, laminal, uncertain, ology, inglis,
# Nearest to channel: upn, ellipsoidal, channels, screened, philatelic, majestic, kantele, harrington,
# Nearest to police: enforcement, scare, aloysius, passports, testimony, writs, marchers, gestapo,
# Nearest to operations: operation, tuples, inverse, yokoi, decimalisation, sparse, georgetown, yong,
# Nearest to bible: jps, synagogues, redacted, scriptures, sunnah, foreskin, enlarged, deacon,
# Epoch 7/10 Iteration: 30100 Avg. Training loss: 3.9078 0.1089 sec/batch
# Epoch 7/10 Iteration: 30200 Avg. Training loss: 3.9415 0.1074 sec/batch
# Epoch 7/10 Iteration: 30300 Avg. Training loss: 3.9176 0.1073 sec/batch
# Epoch 7/10 Iteration: 30400 Avg. Training loss: 3.8847 0.1080 sec/batch
# Epoch 7/10 Iteration: 30500 Avg. Training loss: 3.9492 0.1072 sec/batch
# Epoch 7/10 Iteration: 30600 Avg. Training loss: 3.9232 0.1070 sec/batch
# Epoch 7/10 Iteration: 30700 Avg. Training loss: 3.9245 0.1075 sec/batch
# Epoch 7/10 Iteration: 30800 Avg. Training loss: 3.9194 0.1070 sec/batch
# Epoch 7/10 Iteration: 30900 Avg. Training loss: 3.9220 0.1075 sec/batch
# Epoch 7/10 Iteration: 31000 Avg. Training loss: 3.8763 0.1082 sec/batch
# Epoch 7/10 Iteration: 31100 Avg. Training loss: 3.8925 0.1081 sec/batch
# Epoch 7/10 Iteration: 31200 Avg. Training loss: 3.9117 0.1084 sec/batch
# Epoch 7/10 Iteration: 31300 Avg. Training loss: 3.8845 0.1082 sec/batch
# Epoch 7/10 Iteration: 31400 Avg. Training loss: 3.9611 0.1075 sec/batch
# Epoch 7/10 Iteration: 31500 Avg. Training loss: 3.9702 0.1075 sec/batch
# Epoch 7/10 Iteration: 31600 Avg. Training loss: 3.9697 0.1072 sec/batch
# Epoch 7/10 Iteration: 31700 Avg. Training loss: 3.9068 0.1078 sec/batch
# Epoch 7/10 Iteration: 31800 Avg. Training loss: 3.8679 0.1074 sec/batch
# Epoch 7/10 Iteration: 31900 Avg. Training loss: 3.8939 0.1075 sec/batch
# Epoch 7/10 Iteration: 32000 Avg. Training loss: 3.7819 0.1073 sec/batch
# Epoch 7/10 Iteration: 32100 Avg. Training loss: 3.9101 0.1081 sec/batch
# Epoch 7/10 Iteration: 32200 Avg. Training loss: 3.9381 0.1078 sec/batch
# Epoch 7/10 Iteration: 32300 Avg. Training loss: 3.8994 0.1075 sec/batch
# Epoch 8/10 Iteration: 32400 Avg. Training loss: 3.9376 0.0124 sec/batch
# Epoch 8/10 Iteration: 32500 Avg. Training loss: 3.9026 0.1072 sec/batch
# Epoch 8/10 Iteration: 32600 Avg. Training loss: 3.8596 0.1075 sec/batch
# Epoch 8/10 Iteration: 32700 Avg. Training loss: 3.8454 0.1069 sec/batch
# Epoch 8/10 Iteration: 32800 Avg. Training loss: 3.9122 0.1071 sec/batch
# Epoch 8/10 Iteration: 32900 Avg. Training loss: 3.8587 0.1072 sec/batch
# Epoch 8/10 Iteration: 33000 Avg. Training loss: 3.8702 0.1074 sec/batch
# Epoch 8/10 Iteration: 33100 Avg. Training loss: 3.8344 0.1075 sec/batch
# Epoch 8/10 Iteration: 33200 Avg. Training loss: 3.8857 0.1076 sec/batch
# Epoch 8/10 Iteration: 33300 Avg. Training loss: 3.8675 0.1076 sec/batch
# Epoch 8/10 Iteration: 33400 Avg. Training loss: 3.9107 0.1087 sec/batch
# Epoch 8/10 Iteration: 33500 Avg. Training loss: 3.8711 0.1085 sec/batch
# Epoch 8/10 Iteration: 33600 Avg. Training loss: 3.8364 0.1081 sec/batch
# Epoch 8/10 Iteration: 33700 Avg. Training loss: 3.8351 0.1089 sec/batch
# Epoch 8/10 Iteration: 33800 Avg. Training loss: 3.7905 0.1084 sec/batch
# Epoch 8/10 Iteration: 33900 Avg. Training loss: 3.8626 0.1080 sec/batch
# Epoch 8/10 Iteration: 34000 Avg. Training loss: 3.8878 0.1079 sec/batch
# Epoch 8/10 Iteration: 34100 Avg. Training loss: 3.8637 0.1081 sec/batch
# Epoch 8/10 Iteration: 34200 Avg. Training loss: 3.8622 0.1081 sec/batch
# Epoch 8/10 Iteration: 34300 Avg. Training loss: 3.9398 0.1077 sec/batch
# Epoch 8/10 Iteration: 34400 Avg. Training loss: 3.8976 0.1078 sec/batch
# Epoch 8/10 Iteration: 34500 Avg. Training loss: 3.8458 0.1080 sec/batch
# Epoch 8/10 Iteration: 34600 Avg. Training loss: 3.8757 0.1080 sec/batch
# Epoch 8/10 Iteration: 34700 Avg. Training loss: 3.8854 0.1075 sec/batch
# Epoch 8/10 Iteration: 34800 Avg. Training loss: 3.8742 0.1075 sec/batch
# Epoch 8/10 Iteration: 34900 Avg. Training loss: 3.8746 0.1070 sec/batch
# Epoch 8/10 Iteration: 35000 Avg. Training loss: 3.8989 0.1073 sec/batch
# Epoch 8/10 Iteration: 35100 Avg. Training loss: 3.8716 0.1074 sec/batch
# Epoch 8/10 Iteration: 35200 Avg. Training loss: 3.8679 0.1069 sec/batch
# Epoch 8/10 Iteration: 35300 Avg. Training loss: 3.8644 0.1074 sec/batch
# Epoch 8/10 Iteration: 35400 Avg. Training loss: 3.9144 0.1068 sec/batch
# Epoch 8/10 Iteration: 35500 Avg. Training loss: 3.8731 0.1079 sec/batch
# Epoch 8/10 Iteration: 35600 Avg. Training loss: 3.8882 0.1082 sec/batch
# Epoch 8/10 Iteration: 35700 Avg. Training loss: 3.8436 0.1087 sec/batch
# Epoch 8/10 Iteration: 35800 Avg. Training loss: 3.8709 0.1082 sec/batch
# Epoch 8/10 Iteration: 35900 Avg. Training loss: 3.9472 0.1087 sec/batch
# Epoch 8/10 Iteration: 36000 Avg. Training loss: 3.8789 0.1077 sec/batch
# Epoch 8/10 Iteration: 36100 Avg. Training loss: 3.9646 0.1079 sec/batch
# Epoch 8/10 Iteration: 36200 Avg. Training loss: 3.9481 0.1080 sec/batch
# Epoch 8/10 Iteration: 36300 Avg. Training loss: 3.8900 0.1077 sec/batch
# Epoch 8/10 Iteration: 36400 Avg. Training loss: 3.8656 0.1071 sec/batch
# Epoch 8/10 Iteration: 36500 Avg. Training loss: 3.8612 0.1069 sec/batch
# Epoch 8/10 Iteration: 36600 Avg. Training loss: 3.8382 0.1073 sec/batch
# Epoch 8/10 Iteration: 36700 Avg. Training loss: 3.8630 0.1084 sec/batch
# Epoch 8/10 Iteration: 36800 Avg. Training loss: 3.8893 0.1082 sec/batch
# Epoch 8/10 Iteration: 36900 Avg. Training loss: 3.8679 0.1072 sec/batch
# Epoch 8/10 Iteration: 37000 Avg. Training loss: 3.9071 0.1077 sec/batch
# Epoch 9/10 Iteration: 37100 Avg. Training loss: 3.8812 0.0911 sec/batch
# Epoch 9/10 Iteration: 37200 Avg. Training loss: 3.8531 0.1078 sec/batch
# Epoch 9/10 Iteration: 37300 Avg. Training loss: 3.8485 0.1072 sec/batch
# Epoch 9/10 Iteration: 37400 Avg. Training loss: 3.8928 0.1065 sec/batch
# Epoch 9/10 Iteration: 37500 Avg. Training loss: 3.8269 0.1066 sec/batch
# Epoch 9/10 Iteration: 37600 Avg. Training loss: 3.8416 0.1072 sec/batch
# Epoch 9/10 Iteration: 37700 Avg. Training loss: 3.8062 0.1074 sec/batch
# Epoch 9/10 Iteration: 37800 Avg. Training loss: 3.8420 0.1071 sec/batch
# Epoch 9/10 Iteration: 37900 Avg. Training loss: 3.8649 0.1077 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 3.8749 0.1081 sec/batch
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8809 0.1081 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7473 0.1084 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8287 0.1091 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7847 0.1084 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8536 0.1080 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8705 0.1079 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8610 0.1083 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7951 0.1082 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8722 0.1077 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9157 0.1079 sec/batch
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8365 0.1078 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8898 0.1077 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8861 0.1072 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8364 0.1075 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8454 0.1075 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8814 0.1070 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8542 0.1072 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8544 0.1070 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8801 0.1072 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8598 0.1067 sec/batch
# Nearest to system: systems, multiethnic, whitcomb, educational, universal, local, maintained, lines,
# Nearest to of: the, and, by, in, a, is, on, also,
# Nearest to had: was, been, soon, he, koktebel, his, found, early,
# Nearest to as: the, in, is, of, was, known, a, now,
# Nearest to by: the, of, for, a, to, on, which, s,
# Nearest to known: as, in, found, civilize, considered, was, many, notable,
# Nearest to at: of, that, in, on, the, three, higher, up,
# Nearest to american: gfdl, states, dillinger, americans, contact, fetish, dana, emigrants,
# Nearest to troops: forces, battle, confederates, request, gunboat, honours, salutary, army,
# Nearest to resources: arable, provides, hydropower, extremes, tint, bauxite, schoolteacher, uranhay,
# Nearest to recorded: patti, records, songs, sanusi, demo, live, singles, gross,
# Nearest to accepted: lugano, automated, exceptionalism, inglis, uncertain, leni, commission, nuseibeh,
# Nearest to channel: channels, upn, screened, ellipsoidal, coronation, kantele, broadcasting, aired,
# Nearest to police: enforcement, gestapo, passports, laomedon, aloysius, abigail, scare, dantzig,
# Nearest to operations: operation, sparse, georgetown, decimalisation, garlic, inverse, jafar, yong,
# Nearest to bible: foreskin, redacted, jps, flow, shemot, muddled, fredrick, sunnah,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8813 0.1090 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8256 0.1077 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8200 0.1082 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8474 0.1079 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8952 0.1084 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8570 0.1081 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9670 0.1078 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8920 0.1076 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8772 0.1073 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8047 0.1075 sec/batch
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7788 0.1069 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8708 0.1074 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8050 0.1082 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8575 0.1076 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8202 0.1076 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8765 0.1071 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8904 0.0620 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8270 0.1073 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8326 0.1072 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8580 0.1075 sec/batch
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8318 0.1066 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8355 0.1067 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8375 0.1073 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7943 0.1071 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8600 0.1069 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8287 0.1074 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8752 0.1076 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7446 0.1084 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8080 0.1084 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8089 0.1086 sec/batch
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7498 0.1082 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8149 0.1081 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8434 0.1079 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8172 0.1082 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8176 0.1076 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9093 0.1075 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8322 0.1075 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8206 0.1074 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8431 0.1075 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8496 0.1074 sec/batch
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8622 0.1072 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8329 0.1070 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8107 0.1074 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8605 0.1073 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8782 0.1072 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8515 0.1074 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8163 0.1070 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8493 0.1076 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8140 0.1087 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8202 0.1078 sec/batch
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8460 0.1081 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8328 0.1083 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9360 0.1071 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9193 0.1075 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8760 0.1073 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8358 0.1077 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7530 0.1075 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8536 0.1073 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7410 0.1075 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8518 0.1078 sec/batch
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8484 0.1073 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8217 0.1072 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
